# %% [markdown]
# # nidq_quicklook_and_save
# ### Python port of `main_spikeglx_v4.m`
#
# Quick visualization and export for (1) neural (2) optics (3) slider data.
#
# **Input:** `*.nidq.bin`, `*.nidq.meta` (SpikeGLX), `*.imec0.ap.bin`, `*.imec0.ap.meta`, slider CSV logs, Kilosort4 output.
# **Output:** excerpted raw data + trial/spike summary saved as `.npz` / `.csv`.
#
# Ported 1:1 (function names / behavior preserved) from:
# - `SGLX_readMeta.m` — SpikeGLX meta/bin reader + gain correction
# - `sliderLog.m` — lab-internal CSV/slider-log parsing utility
# - `bpfft.m` — FFT band-pass filter (Rasnow/Assad, EDA Toolbox)
#
# > MATLAB is 1-based; this port keeps 1-based channel indices/lists in the `SGLX_readMeta`
# > methods (to mirror the original math exactly), and converts to 0-based only where numpy
# > arrays are actually sliced.

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
import os
import re
import glob
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) `SGLX_readMeta` — SpikeGLX meta/bin reader + gain correction
# Python port of `SGLX_readMeta.m`. Method names/semantics preserved.

# %%
class SGLX_readMeta:
    """Python port of SGLX_readMeta.m. Method names/semantics preserved."""

    # -----------------------------------------------------------------
    @staticmethod
    def ReadMeta(binName, path):
        """Parse the matching .meta file into a dict of strings."""
        # MATLAB fileparts() strips only the final extension:
        #   'foo.nidq.bin' -> name='foo.nidq'
        name = os.path.splitext(os.path.basename(binName))[0]
        metaName = name + ".meta"
        metaPath = Path(path) / metaName

        meta = {}
        with metaPath.open("r") as f:
            for line in f.read().splitlines():
                if "=" not in line:
                    continue
                tag, _, val = line.partition("=")
                if tag.startswith("~"):
                    tag = tag[1:]
                meta[tag] = val
        return meta

    # -----------------------------------------------------------------
    @staticmethod
    def ReadBin(samp0, nSamp, meta, binName, path):
        """Read nSamp timepoints starting at samp0. Returns [nChan x nSamp]
        float64 array (MATLAB reads as int16=>double)."""
        nChan = int(meta["nSavedChans"])
        nFileSamp = int(meta["fileSizeBytes"]) / (2 * nChan)

        samp0 = max(int(samp0), 0)
        nSamp = int(min(nSamp, nFileSamp - samp0))
        nSamp = max(nSamp, 0)

        binPath = Path(path) / binName
        with open(binPath, "rb") as f:
            f.seek(samp0 * 2 * nChan, os.SEEK_SET)
            count = nSamp * nChan
            raw = np.fromfile(f, dtype="<i2", count=count)

        nRead = raw.size // nChan
        # File is channel-interleaved per timepoint (row-major); MATLAB's
        # fread fills column-major into [nChan,nSamp] -> same result as
        # reshape (nRead, nChan) row-major then transpose.
        dataArray = raw[: nRead * nChan].reshape((nRead, nChan)).T.astype(np.float32)
        return dataArray

    # -----------------------------------------------------------------
    @staticmethod
    def ReadSyncBin(imec_firstSamp, imec_nSamp, imecMeta, imecBinName, binPath, imec_SY):
        """Read only the sync channel (last imec_SY channel(s))."""
        nChan = int(imecMeta["nSavedChans"])
        nFileSamp = int(imecMeta["fileSizeBytes"]) / (2 * nChan)

        imec_firstSamp = max(int(imec_firstSamp), 0)
        imec_nSamp = int(min(imec_nSamp, nFileSamp - imec_firstSamp))
        imec_nSamp = max(imec_nSamp, 0)

        sync_idx = nChan + imec_SY - 1  # 1-based row index of sync channel
        sync_idx0 = sync_idx - 1  # 0-based

        binFullPath = Path(binPath) / imecBinName
        itemsize = 2  # int16
        with open(binFullPath, "rb") as f:
            byteOffset = imec_firstSamp * 2 * nChan + sync_idx0 * itemsize
            f.seek(byteOffset, os.SEEK_SET)
            # Strided read: one int16 every nChan int16's
            raw = np.fromfile(f, dtype="<i2", count=imec_nSamp * nChan)

        # Only every nChan-th sample (starting at 0) belongs to this channel
        nGot = raw.size // nChan
        dataArray = raw[: nGot * nChan].reshape((nGot, nChan))[:, 0].astype(np.float32)
        return dataArray.reshape(1, -1)  # row vector, matches MATLAB .'

    # -----------------------------------------------------------------
    @staticmethod
    def SampRate(meta):
        t = meta.get("typeThis")
        if t == "imec":
            return float(meta["imSampRate"])
        elif t == "nidq":
            return float(meta["niSampRate"])
        elif t == "obx":
            return float(meta["obSampRate"])
        raise KeyError(f"Unknown typeThis: {t}")

    # -----------------------------------------------------------------
    @staticmethod
    def Int2Volts(meta):
        t = meta.get("typeThis")
        if t == "imec":
            maxInt = float(meta["imMaxInt"]) if "imMaxInt" in meta else 512.0
            return float(meta["imAiRangeMax"]) / maxInt
        elif t == "nidq":
            return float(meta["niAiRangeMax"]) / float(meta["niMaxInt"])
        elif t == "obx":
            return float(meta["obAiRangeMax"]) / float(meta["obMaxInt"])
        raise KeyError(f"Unknown typeThis: {t}")

    # -----------------------------------------------------------------
    @staticmethod
    def OriginalChans(meta):
        """Return 1-based list of original (acquired) channel IDs."""
        if meta.get("snsSaveChanSubset") == "all":
            return list(range(1, int(meta["nSavedChans"]) + 1))
        chans0 = _matlab_str2num_list(meta["snsSaveChanSubset"])
        return [c + 1 for c in chans0]

    # -----------------------------------------------------------------
    @staticmethod
    def ChannelCountsIM(meta):
        M = _matlab_str2num_list(meta["snsApLfSy"])
        return int(M[0]), int(M[1]), int(M[2])

    @staticmethod
    def ChannelCountsNI(meta):
        M = _matlab_str2num_list(meta["snsMnMaXaDw"])
        return int(M[0]), int(M[1]), int(M[2]), int(M[3])

    @staticmethod
    def ChannelCountsOBX(meta):
        M = _matlab_str2num_list(meta["snsXaDwSy"])
        return int(M[0]), int(M[1]), int(M[2])

    # -----------------------------------------------------------------
    @staticmethod
    def ChanGainNI(ichan, savedMN, savedMA, meta):
        """ichan is 1-based saved-channel index."""
        if ichan <= savedMN:
            return float(meta["niMNGain"])
        elif ichan <= savedMN + savedMA:
            return float(meta["niMAGain"])
        else:
            return 1.0

    # -----------------------------------------------------------------
    @staticmethod
    def ChanGainsIM(meta):
        np1_imro = [0, 1020, 1030, 1200, 1100, 1120, 1121, 1122, 1123, 1300]
        acqCountList = _matlab_str2num_list(meta["acqApLfSy"])

        APgain = np.zeros(int(acqCountList[0]))
        LFgain = np.zeros(int(acqCountList[1]))

        probeType = float(meta["imDatPrb_type"]) if "imDatPrb_type" in meta else 0

        if probeType in np1_imro:
            APgain, LFgain = _parse_imro_gains(meta["imroTbl"])
        else:
            if "imChan0apGain" in meta:
                APgain = APgain + float(meta["imChan0apGain"])
                if acqCountList[1] > 0:
                    LFgain = LFgain + float(meta["imChan0lfGain"])
            elif probeType == 1110:
                nums = [float(x) for x in re.findall(r"-?\d+", meta["imroTbl"])[:5]]
                APgain = APgain + nums[3]
                LFgain = LFgain + nums[4]
            elif probeType in (21, 24):
                APgain = APgain + 80
            elif probeType == 2013:
                APgain = APgain + 100
            else:
                print("unknown gain, setting APgain to 1")
                APgain = APgain + 1

        fI2V = SGLX_readMeta.Int2Volts(meta)
        APChan0_to_uV = 1e6 * fI2V / APgain[0]
        LFChan0_to_uV = 1e6 * fI2V / LFgain[0] if LFgain.size > 0 else 0
        return APgain, LFgain, APChan0_to_uV, LFChan0_to_uV

    # -----------------------------------------------------------------
    @staticmethod
    def GainCorrectNI(dataArray, chanList, meta):
        """chanList: 1-based saved-channel indices (MATLAB convention)."""
        MN, MA, XA, DW = SGLX_readMeta.ChannelCountsNI(meta)
        fI2V = SGLX_readMeta.Int2Volts(meta)
        out = dataArray  # modify in place (avoid doubling memory)
        for j in chanList:
            conv = fI2V / SGLX_readMeta.ChanGainNI(j, MN, MA, meta)
            out[j - 1, :] = out[j - 1, :] * conv
        return out

    @staticmethod
    def GainCorrectOBX(dataArray, chanList, meta):
        fI2V = SGLX_readMeta.Int2Volts(meta)
        out = dataArray  # modify in place (avoid doubling memory)
        for j in chanList:
            out[j - 1, :] = out[j - 1, :] * fI2V
        return out

    @staticmethod
    def GainCorrectIM(dataArray, chanList, meta):
        """chanList: 1-based saved-channel indices (MATLAB convention)."""
        chans = SGLX_readMeta.OriginalChans(meta)  # 1-based, len == nSavedChans
        APgain, LFgain, _, _ = SGLX_readMeta.ChanGainsIM(meta)
        nAP = len(APgain)
        nNu = nAP * 2

        fI2V = SGLX_readMeta.Int2Volts(meta)
        out = dataArray  # modify in place (avoid doubling memory)
        for j in chanList:
            k = chans[j - 1]  # acquisition index (1-based)
            if k <= nAP:
                conv = fI2V / APgain[k - 1]
            elif k <= nNu:
                conv = fI2V / LFgain[k - nAP - 1]
            else:
                continue
            out[j - 1, :] = out[j - 1, :] * conv
        return out

    # -----------------------------------------------------------------
    @staticmethod
    def ExtractDigital(dataArray, meta, dwReq, dLineList):
        t = meta.get("typeThis")
        if t == "imec":
            AP, LF, SY = SGLX_readMeta.ChannelCountsIM(meta)
            if SY == 0:
                print("No imec sync channel saved")
                return np.zeros((0, dataArray.shape[1]), dtype=np.uint8)
            digCh = AP + LF + dwReq
        elif t == "nidq":
            MN, MA, XA, DW = SGLX_readMeta.ChannelCountsNI(meta)
            if dwReq > DW:
                print(f"Maximum digital word in file = {DW}")
                return np.zeros((0, dataArray.shape[1]), dtype=np.uint8)
            digCh = MN + MA + XA + dwReq
        elif t == "obx":
            XA, DW, SY = SGLX_readMeta.ChannelCountsOBX(meta)
            if dwReq > DW:
                print(f"Maximum digital word in file = {DW}")
                return np.zeros((0, dataArray.shape[1]), dtype=np.uint8)
            digCh = XA + dwReq
        else:
            raise KeyError(f"Unknown typeThis: {t}")

        nSamp = dataArray.shape[1]
        digArray = np.zeros((len(dLineList), nSamp), dtype=np.uint8)
        word = dataArray[digCh - 1, :].astype(np.int16)
        for i, line in enumerate(dLineList):
            digArray[i, :] = (word >> line) & 1
        return digArray

    # -----------------------------------------------------------------
    @staticmethod
    def parseFileName(fileName):
        if fileName.endswith(".bin"):
            fileName = fileName[: -len(".bin")]
        elif fileName.endswith(".meta"):
            fileName = fileName[: -len(".meta")]

        perPos = [i for i, c in enumerate(fileName) if c == "."]
        usPos = [i for i, c in enumerate(fileName) if c == "_"]

        streamStr = fileName[perPos[-1] + 1 :]
        probeStr = fileName[perPos[-2] + 1 : perPos[-1]]
        triggerStr = fileName[usPos[-1] + 1 : perPos[-2]]
        gateStr = fileName[usPos[-2] + 1 : usPos[-1]]
        runName = fileName[: usPos[-2]]
        return runName, gateStr, triggerStr, probeStr, streamStr


def _matlab_str2num_list(s):
    """Parse a MATLAB str2num-style numeric list, e.g. '384,0,1' or
    '0:33,36:37,40' into a flat list of ints/floats."""
    vals = []
    for part in s.split(","):
        part = part.strip()
        if not part:
            continue
        if ":" in part:
            lo, hi = part.split(":")
            vals.extend(range(int(lo), int(hi) + 1))
        else:
            vals.append(float(part) if "." in part else int(part))
    return vals


def _parse_imro_gains(imroTbl):
    """Parse AP/LF gain columns out of the imro table string.
    Groups look like '(header)(chan bank refid apgain lfgain [hp])...'.
    Skip the header group; for each channel group take tokens[3],[4].
    """
    groups = re.findall(r"\(([^)]*)\)", imroTbl)
    body = groups[1:]  # skip header (HeaderLines=1 in original)
    APgain, LFgain = [], []
    for g in body:
        toks = g.split()
        if len(toks) < 5:
            continue
        APgain.append(float(toks[3]))
        LFgain.append(float(toks[4]))
    return np.array(APgain), np.array(LFgain)

# %% [markdown]
# ## 2) `bpfft` — FFT band-pass filter
# Direct port of `bpfft.m` (Rasnow/Assad, EDA Toolbox).

# %%
def bpfft(v, rate, fo, f1):
    """Band-pass fft filter, pass band fo < f < f1 (Hz).
    Direct port of bpfft.m; operates on a 1-D signal."""
    v = np.asarray(v, dtype=float).ravel()
    n = v.size

    ffo = int(round(fo * n / rate))
    ff1 = int(round(f1 * n / rate))
    fb = np.fft.fft(v)

    if fo == 0:
        ffo = -1

    # MATLAB 1-based ranges: [1:ffo+1, ff1+1:n-ff1+1, n-ffo+1:n]
    idx = []
    if ffo + 1 >= 1:
        idx.append(np.arange(1, ffo + 2))
    lo2, hi2 = ff1 + 1, n - ff1 + 1
    if hi2 >= lo2:
        idx.append(np.arange(lo2, hi2 + 1))
    lo3, hi3 = n - ffo + 1, n
    if hi3 >= lo3:
        idx.append(np.arange(lo3, hi3 + 1))

    if idx:
        idx = np.concatenate(idx) - 1  # to 0-based
        idx = idx[(idx >= 0) & (idx < n)]
        fb[idx] = 0

    d = np.real(np.fft.ifft(fb))
    return d

# %% [markdown]
# ## 3) `sliderLog` — slider CSV log parsing/classification
# Python port of `sliderLog.m`.

# %%
class sliderLog:
    """Python port of sliderLog.m."""

    @staticmethod
    def getCsv(csvFiles):
        """csvFiles: list of full paths to .csv files (already filtered)."""
        csvData = []
        for f in csvFiles:
            csvData.append((os.path.basename(f), pd.read_csv(f)))

        for i, (name, _) in enumerate(csvData):
            print(f"[{i + 1}] {name}")
        j = int(input("Insert related csv file number: ")) - 1
        csvName = csvData[j][0]
        print(csvName)
        data = csvData[j][1]
        return csvData, csvName, data

    @staticmethod
    def classifyCsv(data, motor_start, motor_end):
        data = data.copy()

        # 1) Make corrected angle: if direction==0, add 180 degrees
        idx = data["direction"] == 0
        data.loc[idx, "stepper_ang"] = data.loc[idx, "stepper_ang"] + 180

        # 2) Find unique speeds and angles
        spList = np.sort(data["cmd_speed"].unique())
        angList = np.sort(data["stepper_ang"].unique())

        # 3) data form change
        motor_start = np.asarray(motor_start)
        motor_end = np.asarray(motor_end)

        data["nidq_start"] = motor_start
        start_time = pd.to_datetime(data["start_time"])
        end_time = pd.to_datetime(data["end_time"])
        data["log_dur"] = (end_time - start_time).dt.total_seconds()
        data["trig_dur"] = motor_end - motor_start
        data["log_end"] = data["nidq_start"] + data["log_dur"]
        data["trig_end"] = motor_end

        data = data.drop(columns=["direction", "result", "notes", "end_time"], errors="ignore")
        return spList, angList, data

    @staticmethod
    def groupingCsv(data, spList, angList):
        csvGroup = {}
        for sp in spList:
            spField = make_valid_name(f"sp_{sp:g}")
            spTable = data[data["cmd_speed"] == sp]
            csvGroup[spField] = {}
            for ang in angList:
                angField = make_valid_name(f"ang_{ang:g}")
                angTable = spTable[spTable["stepper_ang"] == ang].reset_index(drop=True)
                csvGroup[spField][angField] = angTable

        repeatTime = len(data) / (len(spList) * len(angList))
        return csvGroup, repeatTime

# %% [markdown]
# ## Helper functions
# NPY / TSV readers and `matlab.lang.makeValidName` equivalent.

# %%
def read_npy(path):
    return np.load(path)


def read_cluster_kslabel_tsv(tsv_path):
    return pd.read_csv(
        tsv_path, sep="\t", header=0, names=["cluster_id", "KSLabel"],
        dtype={"cluster_id": float, "KSLabel": str},
    )


def make_valid_name(s):
    """Equivalent of matlab.lang.makeValidName (simplified)."""
    s = re.sub(r"[^0-9a-zA-Z_]", "_", str(s))
    if not s or not s[0].isalpha():
        s = "x" + s
    return s

def downsample_for_plot(t, x, max_points=200_000):
    """Stride-decimate t (1D) and x (last axis matches t) so plotting a very
    long trace doesn't try to render millions of points (-> MemoryError).
    Only affects the plot; underlying full-resolution arrays are untouched."""
    n = t.shape[-1]
    step = max(1, n // max_points)
    return t[::step], x[..., ::step]

# %% [markdown]
# ## **Main workflow**

# %% [markdown]
# ### getData: start from step01_rawData

# %%
# Windows absolute path -- use a raw string (r"...") so backslashes
# aren't treated as escape characters, or use forward slashes instead.
folderPath = r"D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17"

assert os.path.isdir(folderPath), f"Folder not found: {folderPath}"

allFiles = glob.glob(os.path.join(folderPath, "**", "*"), recursive=True)
binNidqFiles = [f for f in allFiles if f.endswith(".nidq.bin")]
binImecFiles = [f for f in allFiles if f.endswith(".imec0.ap.bin")]
csvFiles = [f for f in allFiles if f.endswith(".csv")]

print(f"Found {len(binNidqFiles)} nidq.bin, {len(binImecFiles)} imec0.ap.bin, {len(csvFiles)} csv files")

print("\nbinNidqFiles:")
for idx, f in enumerate(binNidqFiles):
    print(f"[{idx + 1}] {f}")
# Out:
# Found 18 nidq.bin, 10 imec0.ap.bin, 31 csv files
#
# binNidqFiles:
# [1] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1320_g0\rat17_ap3000_ml4600_dv1320_g0_t0.nidq.bin
# [2] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1600_02_g0\rat17_ap3000_ml4600_dv1600_02_g0_t0.nidq.bin
# [3] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1600_02_g0\copy\rat17_ap3000_ml4600_dv1600_02_g0_t0.nidq.bin
# [4] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1600_B4_g0\rat17_ap3000_ml4600_dv1600_B4_g0_t0.nidq.bin
# [5] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1600_g0\rat17_ap3000_ml4600_dv1600_g0_t0.nidq.bin
# [6] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3000_ml4600_dv1600_sur_g0\rat17_ap3000_ml4600_dv1600_sur_g0_t0.nidq.bin
# [7] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1500_02_g0\rat17_ap3200_ml5100_dv1500_02_g0_t0.nidq.bin
# [8] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1500_03_g0\rat17_ap3200_ml5100_dv1500_03_g0_t0.nidq.bin
# [9] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1500_03_g1\rat17_ap3200_ml5100_dv1500_03_g1_t0.nidq.bin
# [10] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1500_g0\rat17_ap3200_ml5100_dv1500_g0_t0.nidq.bin
# [11] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1700_02_g0\rat17_ap3200_ml5100_dv1700_02_g0_t0.nidq.bin
# [12] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3200_ml5100_dv1700_g0\rat17_ap3200_ml5100_dv1700_g0_t0.nidq.bin
# [13] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3450_ml4600_dv1580_g1\rat17_ap3450_ml4600_dv1580_g1_t0.nidq.bin
# [14] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_ap3450_ml4600_dv1800_g0\rat17_ap3450_ml4600_dv1800_g0_t0.nidq.bin
# [15] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_cal_01_g0\rat17_cal_01_g0_t0.nidq.bin
# [16] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_cal_02_g0\rat17_cal_02_g0_t0.nidq.bin
# [17] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_cal_03_g1\rat17_cal_03_g1_t0.nidq.bin
# [18] D:\OneDrive - Northwestern University\0_Research\00_JiyeonSharepoint\Project_S1BF\step01_rawData\expt_260605_rat17\rat17_cal_04_g1\rat17_cal_04_g1_t0.nidq.bin

# %% [markdown]
# ### setting: open binImecFiles first and figure out the order of neural data

# %%
j = int(input("which neural data number do you want to analysis? ")) - 1  # MATLAB is 1-indexed
imecFilePath = binImecFiles[j]
binPath = os.path.dirname(imecFilePath)
binNameFull = os.path.basename(imecFilePath)
binName = binNameFull[: -len(".imec0.ap.bin")]
print(binName)

# 1) Read metadata
imecBinName = binName + ".imec0.ap.bin"
imecMeta = SGLX_readMeta.ReadMeta(imecBinName, binPath)

nidqBinName = binName + ".nidq.bin"
nidqParentPath = os.path.dirname(binPath)  # fileparts(binPath)
nidqMeta = SGLX_readMeta.ReadMeta(nidqBinName, nidqParentPath)

rec_time = float(imecMeta["fileTimeSecs"])  # imec/nidq timesecs differ slightly, ignored
print(rec_time)
# Out:
# which neural data number do you want to analysis?  2
# rat17_ap3000_ml4600_dv1600_02_g0_t0
# 910.8197

# %% [markdown]
# ### Time window to read (s)

# %%
t0_sec = 200  # Start time
dur_sec = 10  # Duration to read
# dur_sec = rec_time

# %% [markdown]
# ### 1-1) nidq data

# %%
nidq_fs = float(nidqMeta["niSampRate"])

nidq_firstSamp = max(0, round(0 * nidq_fs))
nidq_nSamp = max(1, round(rec_time * nidq_fs))

nidq_raw = SGLX_readMeta.ReadBin(nidq_firstSamp, nidq_nSamp, nidqMeta, nidqBinName, nidqParentPath)
nidq_V = SGLX_readMeta.GainCorrectNI(nidq_raw, range(1, nidq_raw.shape[0] + 1), nidqMeta)

nidq_t = np.arange(nidq_V.shape[1]) / nidq_fs

# %% [markdown]
# ### 1-2) neural data — bombcell/Kilosort spike-sorted units
# Replaces the original raw `.imec0.ap.bin` read + 300–3000 Hz band-pass filter with **already spike-sorted / bombcell-curated units**, loaded directly from disk.

# %%
imec_fs = float(imecMeta["imSampRate"])
imec_AP, imec_LF, imec_SY = SGLX_readMeta.ChannelCountsIM(imecMeta)

# ---------------------------------------------------------------
# Use spike-sorted / bombcell-curated units instead of raw AP-band
# voltage traces. bombcell & Kilosort outputs are expected in the
# SAME folder as the raw .imec0.ap.bin/.meta files (binPath).
# If yours live in a subfolder instead (e.g. binPath/kilosort4),
# just change ksDir below.
# ---------------------------------------------------------------
ksDir = os.path.join(binPath, "kilosort4")
spike_times = read_npy(os.path.join(ksDir, "spike_times.npy"))       # sample index per spike
spike_clusters = read_npy(os.path.join(ksDir, "spike_clusters.npy")) # cluster/template id per spike
spike_sec = spike_times.astype(float) / imec_fs                      # -> seconds

templates = read_npy(os.path.join(ksDir, "templates.npy"))
channel_positions = read_npy(os.path.join(ksDir, "channel_positions.npy"))

# Prefer bombcell's unit classification (cluster_bc_unitType.tsv, label
# 'GOOD'); fall back to Kilosort's own cluster_KSLabel.tsv (label 'good')
# if bombcell output isn't present.
bcFile = os.path.join(ksDir, "cluster_bc_unitType.tsv")
ksFile = os.path.join(ksDir, "cluster_KSLabel.tsv")

if os.path.exists(bcFile):
    clusterLabels = pd.read_csv(bcFile, sep="\t")
    goodClusters = clusterLabels.loc[clusterLabels["bc_unitType"] == "GOOD", "cluster_id"].to_numpy()
    print(f"Using bombcell labels ({os.path.basename(bcFile)}): {len(goodClusters)} good units")
else:
    clusterLabels = read_cluster_kslabel_tsv(ksFile)
    goodClusters = clusterLabels.loc[clusterLabels["KSLabel"] == "good", "cluster_id"].to_numpy()
    print(f"bombcell labels not found -- using Kilosort labels ({os.path.basename(ksFile)}): {len(goodClusters)} good units")

idxGoodSpike = np.isin(spike_clusters.astype(float), goodClusters)
spike_sec = spike_sec[idxGoodSpike]
spike_clusters = spike_clusters[idxGoodSpike]
goodClusterIDs = np.sort(goodClusters)

print(f"{len(goodClusterIDs)} good units, {spike_sec.size} total spikes")
binNidqFiles
# Out:
# Using bombcell labels (cluster_bc_unitType.tsv): 16 good units
# 16 good units, 38634 total spikes
# ['D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1320_g0\\rat17_ap3000_ml4600_dv1320_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1600_02_g0\\rat17_ap3000_ml4600_dv1600_02_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1600_02_g0\\copy\\rat17_ap3000_ml4600_dv1600_02_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1600_B4_g0\\rat17_ap3000_ml4600_dv1600_B4_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1600_g0\\rat17_ap3000_ml4600_dv1600_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3000_ml4600_dv1600_sur_g0\\rat17_ap3000_ml4600_dv1600_sur_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1500_02_g0\\rat17_ap3200_ml5100_dv1500_02_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1500_03_g0\\rat17_ap3200_ml5100_dv1500_03_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1500_03_g1\\rat17_ap3200_ml5100_dv1500_03_g1_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1500_g0\\rat17_ap3200_ml5100_dv1500_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1700_02_g0\\rat17_ap3200_ml5100_dv1700_02_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3200_ml5100_dv1700_g0\\rat17_ap3200_ml5100_dv1700_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3450_ml4600_dv1580_g1\\rat17_ap3450_ml4600_dv1580_g1_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_ap3450_ml4600_dv1800_g0\\rat17_ap3450_ml4600_dv1800_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_cal_01_g0\\rat17_cal_01_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_cal_02_g0\\rat17_cal_02_g0_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_cal_03_g1\\rat17_cal_03_g1_t0.nidq.bin',
#  'D:\\OneDrive - Northwestern University\\0_Research\\00_JiyeonSharepoint\\Project_S1BF\\step01_rawData\\expt_260605_rat17\\rat17_cal_04_g1\\rat17_cal_04_g1_t0.nidq.bin']

# %% [markdown]
# ### 1-3) calibration data

# %%
j2 = int(input("which calibration data number do you want to use? ")) - 1
calFilePath = binNidqFiles[j2]
calBinPath = os.path.dirname(calFilePath)
calBinName = os.path.basename(calFilePath)
print(calBinName)

calMeta = SGLX_readMeta.ReadMeta(calBinName, calBinPath)
# Out:
# which calibration data number do you want to use?  18
# rat17_cal_04_g1_t0.nidq.bin

# %% [markdown]
# ### 4) Visualization

# %%
figureOffset = 0
nidq_Wstart = int(t0_sec * nidq_fs)
nidq_Wend = int((t0_sec + dur_sec) * nidq_fs)

plt.figure()
for i in range(3):
    trace = nidq_V[i, nidq_Wstart:nidq_Wend]
    plt.plot(nidq_t[nidq_Wstart:nidq_Wend], trace + figureOffset)
plt.xlabel("Time (s)")
plt.ylabel("Voltage [V]")
plt.title("NIDQ Traces")
plt.legend(["Slider position", "Optic", "Trigger"], loc="best")
plt.grid(True)
plt.tight_layout()

# Neural data: spike raster of good (bombcell/Kilosort) units,
# whole recording
plt.figure(figsize=(14, 6))
ax = plt.gca()
window_spikes = []
for cid in goodClusterIDs:
    st = spike_sec[spike_clusters == cid]
    window_spikes.append(st)
ax.eventplot(window_spikes, colors="black", lineoffsets=goodClusterIDs, linelengths=0.8)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Cluster ID")
ax.set_yticks(goodClusterIDs)
ax.set_title(f"Spike raster: {binName} ({len(goodClusterIDs)} good units, full recording)")
plt.grid(True)
plt.tight_layout()

# %%
figureOffset = 0
nidq_fs = float(nidqMeta["niSampRate"])
nidq_Chan = 3
nidq_nSamp = max(1, round(rec_time * nidq_fs))
nidq_raw = SGLX_readMeta.ReadBin(0, nidq_nSamp, nidqMeta, nidqBinName, nidqParentPath)
nidq_t = np.arange(nidq_raw.shape[1]) / nidq_fs
nidq_Wstart = 0
nidq_Wend = max(1, round(rec_time * nidq_fs))

nidqLabels = ["Slider position", "Optic", "Trigger"]

winStart = rising_indices
winEnd = falling_indices

# %% [markdown]
# ### figure) WHOLE nidq data -- SUPPLEMENTARY

# %%
print("Good cluster IDs:")
for idx, cid in enumerate(goodClusterIDs):
    n_spikes = int(np.sum(spike_clusters == cid))
    print(f"[{idx + 1}] cluster {cid}  ({n_spikes} spikes)")

spike_sec_all = spike_sec
spike_clusters_all = spike_clusters

sel = int(input("Select cluster number: ")) - 1
selected_cluster = goodClusterIDs[sel]

# From here on, spike_sec / spike_clusters only contain this one unit's spikes.
mask = spike_clusters == selected_cluster
spike_sec = spike_sec_all[mask]
spike_clusters = spike_clusters_all[mask]

print(f"\n Selected cluster: {selected_cluster}  (spikes: {spike_sec.size})")
# Out:
# Good cluster IDs:
# [1] cluster 0  (342 spikes)
# [2] cluster 86  (2932 spikes)
# [3] cluster 208  (2287 spikes)
# [4] cluster 217  (1847 spikes)
# [5] cluster 233  (1058 spikes)
# [6] cluster 269  (1191 spikes)
# [7] cluster 309  (775 spikes)
# [8] cluster 338  (12794 spikes)
# [9] cluster 346  (5516 spikes)
# [10] cluster 347  (675 spikes)
# [11] cluster 350  (3264 spikes)
# [12] cluster 356  (347 spikes)
# [13] cluster 364  (521 spikes)
# [14] cluster 365  (623 spikes)
# [15] cluster 369  (3307 spikes)
# [16] cluster 410  (1155 spikes)
# Select cluster number:  1
#  Selected cluster: 0  (spikes: 342)

# %% [markdown]
# ### 5) Extract Trigger Onset Times (Rising Edges)

# %%
trigger_signal = nidq_V[2, :]  # channel 3 (1-based in MATLAB) -> index 2

thr_down = 0.1
thr_up = 2.2

above_up = trigger_signal > thr_up
below_down = trigger_signal < thr_down
rising_indices = np.where(np.diff(above_up.astype(int)) == 1)[0] + 1
falling_indices = np.where(np.diff(below_down.astype(int)) == 1)[0] - 1

motor_start = nidq_t[rising_indices]
motor_end = nidq_t[falling_indices]

csvData, csvName, oneCsv = sliderLog.getCsv(csvFiles)
spList, angList, updateCsv = sliderLog.classifyCsv(oneCsv, motor_start, motor_end)
# Out:
# [1] rat17_ap3000_ml4600_dv1320_2026-06-05-22-01-40.csv
# [2] rat17_ap3000_ml4600_dv1600_02_2026-06-05-23-05-05.csv
# [3] rat17_ap3000_ml4600_dv1600_2026-06-05-22-28-58.csv
# [4] rat17_ap3000_ml4600_dv1600_B4_2026-06-06-00-06-30.csv
# [5] rat17_ap3000_ml4600_dv1600_sur_2026-06-05-23-47-02.csv
# [6] rat17_ap3200_ml4600_dv1580_2026-06-05-17-50-43.csv
# [7] rat17_ap3200_ml4600_dv1800_2026-06-05-18-28-21.csv
# [8] rat17_ap3200_ml5100_dv1500_02_2026-06-05-19-47-47.csv
# [9] rat17_ap3200_ml5100_dv1500_03_2026-06-05-20-17-37.csv
# [10] rat17_ap3200_ml5100_dv1500_2026-06-05-19-12-47.csv
# [11] rat17_ap3200_ml5100_dv1700_2026-06-05-20-46-20.csv
# [12] rat17_ap3200_ml5100_dv1700_2_2026-06-05-21-26-52.csv
# [13] rat17_cal_01_2026-06-05-14-00-42.csv
# [14] rat17_cal_01_2026-06-05-15-32-46.csv
# [15] rat17_cal_02_2026-06-05-19-41-58.csv
# [16] rat17_cal_03_2026-06-05-20-07-29.csv
# [17] rat17_cal_04_2026-06-05-22-57-32.csv
# [18] rat17_cal_post_2026-06-06-00-34-16.csv
# [19] rat17_test_01_2026-06-05-22-47-19.csv
# [20] rat17_test_cal_2026-06-05-15-10-20.csv
# [21] rat17_test_cal_2026-06-05-15-21-28.csv
# [22] RecInfoWOspikeTiming.csv
# [23] rat17_cal_01_2026-06-05-15-32-46.csv
# [24] manual_unit_classifications.csv
# [25] manual_vs_bombcell_classifications.csv
# [26] templates._bc_qMetrics.csv
# [27] _bc_parameters._bc_qMetrics.csv
# [28] manual_unit_classifications.csv
# [29] manual_vs_bombcell_classifications.csv
# [30] templates._bc_qMetrics.csv
# [31] _bc_parameters._bc_qMetrics.csv
# Insert related csv file number:  2
# rat17_ap3000_ml4600_dv1600_02_2026-06-05-23-05-05.csv
# C:\Users\Admir\AppData\Local\Temp\ipykernel_18104\643643587.py:36: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   start_time = pd.to_datetime(data["start_time"])
# C:\Users\Admir\AppData\Local\Temp\ipykernel_18104\643643587.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   end_time = pd.to_datetime(data["end_time"])

# %%
### (1) figure for checking spike_sec chronically

# %%
updateCsv = updateCsv.reset_index(drop=True)
spike_timing = [None] * len(motor_start)
spike_rates = np.zeros(len(motor_start))

plt.figure()
for k in range(len(motor_start)):
    tStart = updateCsv["nidq_start"].iloc[k]
    tEnd = updateCsv["trig_end"].iloc[k]
    idx = (spike_sec >= tStart) & (spike_sec <= tEnd)

    plt.plot([tStart, tEnd], [k + 1, k + 1], color=(0.6, 0.6, 0.6), linewidth=2)
    plt.plot(spike_sec[idx], (k + 1) * np.ones(idx.sum()), ".", markersize=8)

    spike_timing[k] = spike_sec[idx]
    spike_rates[k] = idx.sum() / updateCsv["log_dur"].iloc[k]

plt.xlabel("Time (s)")
plt.ylabel("Trial")
plt.title("Spike times within each NIDQ window")
plt.grid(True)
plt.tight_layout()

updateCsv["spike_timing"] = spike_timing
updateCsv["spike_rates"] = spike_rates

outParent = os.path.dirname(binPath)
np.savez(os.path.join(outParent, "RecordingInfo.npz"), updateCsv=updateCsv.to_dict("list"))
updateCsv_save = updateCsv.drop(columns=["spike_timing"], errors="ignore")
updateCsv_save.to_csv(os.path.join(outParent, "RecInfoWOspikeTiming.csv"), index=False)

csvGroup, repeatTime = sliderLog.groupingCsv(updateCsv, spList, angList)

# %% [markdown]
# ### (2-1) figure for checking spike_sec on each window

# %%
plt.figure()
for k in range(len(motor_start)):
    t0 = updateCsv["nidq_start"].iloc[k]
    t1 = updateCsv["trig_dur"].iloc[k]
    idx = (spike_sec >= t0) & (spike_sec <= t0 + t1)
    spRel = spike_sec[idx] - t0

    plt.plot([0, t1], [k + 1, k + 1], color=(0.6, 0.6, 0.6), linewidth=2)
    plt.plot(spRel, (k + 1) * np.ones(spRel.size), ".", markersize=8)

plt.xlabel("Time (s)")
plt.ylabel("Trial")
plt.title("Spike times within each NIDQ window trial")
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# ### (2-2) figures for checking spike_sec on each window - y axis: speed

# %%
plt.figure()
for k in range(len(motor_start)):
    t0 = updateCsv["nidq_start"].iloc[k]
    t1 = updateCsv["trig_dur"].iloc[k]
    idx = (spike_sec >= t0) & (spike_sec <= t0 + t1)
    spRel = spike_sec[idx] - t0

    cmd_speed_k = updateCsv["cmd_speed"].iloc[k]
    ybase = int(np.where(spList == cmd_speed_k)[0][0]) + 1
    sameSpeedIdx = np.where(updateCsv["cmd_speed"].iloc[: k + 1].to_numpy() == cmd_speed_k)[0]
    repeatNum = sameSpeedIdx.size
    yval = ybase + 0.01 * repeatNum

    #plt.plot([0, t1], [yval, yval], color=(0.6, 0.6, 0.6), linewidth=2)
    plt.plot(spRel, yval * np.ones(spRel.size), ".", markersize=8)

plt.xlabel("Time (s)")
plt.ylabel("Speed")
plt.title("Spike times within each speed (gray: window length)")
plt.yticks(np.arange(1, len(spList) + 1) + 0.4, [str(s) for s in spList])
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# ### (3-1) figures for each group

# %%
outDir = os.path.join(os.path.dirname(binPath), "spikeFigures")
os.makedirs(outDir, exist_ok=True)

for sp in spList:
    spName = make_valid_name(f"sp_{sp:g}")
    yLabels = np.ones(int(round(repeatTime)))

    for ang in angList:
        angName = make_valid_name(f"ang_{ang:g}")
        T = csvGroup[spName][angName]

        plt.figure()
        for k in range(len(T)):
            spRel = np.asarray(T["spike_timing"].iloc[k]) - T["nidq_start"].iloc[k]
            yLabels[k] = T["spike_rates"].iloc[k]
            t1 = T["trig_dur"].iloc[k]

            plt.plot([0, t1], [k + 1, k + 1], color=(0.6, 0.6, 0.6), linewidth=2)
            plt.plot(spRel, (k + 1) * np.ones(spRel.size), "k.", markersize=8)

        plt.xlabel("Spike Timing [sec]")
        plt.ylabel("Trials (Value: SpikeRates [spikes/sec])")
        plt.yticks(np.arange(1, k + 2), [str(y) for y in yLabels[: k + 1]])
        figTitle = f"Speed {sp:g}, Angle {ang:g}, AvgSpikeRates {np.mean(yLabels):.0f}"
        plt.title(figTitle)
        plt.grid(True)
        plt.tight_layout()

        fileName = make_valid_name(figTitle)
        # plt.savefig(os.path.join(outDir, fileName + ".png"))
# Out:
# C:\Users\Admir\AppData\Local\Temp\ipykernel_18104\2717172933.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# ### (3-2) figures for each speed or angle

# %%
cmap_ang = plt.cm.tab10(np.linspace(0, 1, len(angList)))
for sp in spList:
    spName = make_valid_name(f"sp_{sp:g}")

    plt.figure()
    y = 0
    yLabels = []

    for jj, ang in enumerate(angList):
        angName = make_valid_name(f"ang_{ang:g}")
        T = csvGroup[spName][angName]

        for k in range(len(T)):
            y += 1
            spRel = np.asarray(T["spike_timing"].iloc[k]) - T["nidq_start"].iloc[k]
            yLabels.append(T["spike_rates"].iloc[k])
            t1 = T["trig_dur"].iloc[k]

            plt.plot([0, t1], [y, y], color=(0.6, 0.6, 0.6), linewidth=2)
            plt.plot(spRel, y * np.ones(spRel.size), ".", color=cmap_ang[jj], markersize=8)

    plt.xlabel("Spike Timing [sec]")
    plt.ylabel("Trials (Value: SpikeRates [spikes/sec])")
    plt.yticks(np.arange(1, y + 1), [str(v) for v in yLabels])
    figTitle = f"Speed: {sp:g} [cm/s]; Avg spike rates = {np.mean(yLabels):g}"
    plt.title(figTitle)
    plt.grid(True)
    plt.tight_layout()

    fileName = make_valid_name(figTitle)
    # plt.savefig(os.path.join(outDir, fileName + ".png"))

cmap_sp = plt.cm.tab10(np.linspace(0, 1, len(spList)))
for ang in angList:
    angName = make_valid_name(f"ang_{ang:g}")

    plt.figure()
    y = 0
    yLabels = []

    for i, sp in enumerate(spList):
        spName = make_valid_name(f"sp_{sp:g}")
        T = csvGroup[spName][angName]

        for k in range(len(T)):
            y += 1
            spRel = np.asarray(T["spike_timing"].iloc[k]) - T["nidq_start"].iloc[k]
            yLabels.append(T["spike_rates"].iloc[k])
            t1 = T["trig_dur"].iloc[k]

            plt.plot([0, t1], [y, y], color=(0.6, 0.6, 0.6), linewidth=2)
            plt.plot(spRel, y * np.ones(spRel.size), ".", color=cmap_sp[i], markersize=8)

    plt.xlabel("Spike Timing [sec]")
    plt.ylabel("Trials (Value: SpikeRates [spikes/sec])")
    plt.yticks(np.arange(1, y + 1), [str(v) for v in yLabels])
    figTitle = f"Angle: {ang:g} [deg]; Avg spike rates = {np.mean(yLabels):g}"
    plt.title(figTitle)
    plt.grid(True)
    plt.tight_layout()

    fileName = make_valid_name(figTitle)
    # plt.savefig(os.path.join(outDir, fileName + ".png"))

# %% [markdown]
# ### Bar graph for analysis

# %% [markdown]
# #### Speed: 4 figures

# %%
preColor = (0.85, 0.1, 0.1)   # red
stimColor = (0.1, 0.3, 0.9)   # blue

# 1) Speed: 4 figures
for sp in spList:
    Tsub = Tb[Tb["speed"] == sp].sort_values("angle")

    x = np.arange(len(Tsub))
    width = 0.35
    plt.figure()
    plt.bar(x - width / 2, Tsub["pre_rates"], width, color=preColor, label="Pre rate")
    plt.bar(x + width / 2, Tsub["stim_rates"], width, color=stimColor, label="Stim rate")
    plt.xticks(x, [str(a) for a in Tsub["angle"]])

    plt.xlabel("Direction / Angle [deg]")
    plt.ylabel("Spike rate [spikes/sec]")
    figTitle = f"Speed = {sp:g}"
    plt.title(figTitle)
    plt.legend(loc="best")
    plt.grid(True)
    plt.box(False)
    plt.tight_layout()

    fileName = make_valid_name(figTitle)
    # plt.savefig(os.path.join(outDir, fileName + ".png"))

# %% [markdown]
# #### Direction: 8 figures

# %%
# 2) Direction: 8 figures
for ang in angList:
    Tsub = Tb[Tb["angle"] == ang].sort_values("speed")

    x = np.arange(len(Tsub))
    width = 0.35
    plt.figure()
    plt.bar(x - width / 2, Tsub["pre_rates"], width, color=preColor, label="Pre rate")
    plt.bar(x + width / 2, Tsub["stim_rates"], width, color=stimColor, label="Stim rate")
    plt.xticks(x, [str(s) for s in Tsub["speed"]])

    plt.xlabel("Speed [mm/sec]")
    plt.ylabel("Spike rate [spikes/sec]")
    figTitle = f"Direction / Angle = {ang:g}"
    plt.title(figTitle)
    plt.legend(loc="best")
    plt.grid(True)
    plt.box(False)
    plt.tight_layout()

    fileName = make_valid_name(figTitle)
    # plt.savefig(os.path.join(outDir, fileName + ".png"))

plt.show()
